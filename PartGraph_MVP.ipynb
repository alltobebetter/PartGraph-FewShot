# %% [markdown]
# # PartGraph MVP - Colab Runner
#
# This notebook allows you to run the Minimum Viable Product (MVP) test for the PartGraph project.
# It verifies that the Slot Attention and ResNet backbone are working correctly.

# %%
# 1. Clone the Repository
# If you are running this from the repo itself in Colab, you might not need to clone again if you opened it via GitHub integration.
# However, to be safe and ensure latest code:
# !git clone https://github.com/alltobebetter/PartGraph-FewShot.git
# %cd PartGraph-FewShot

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Run the MVP Test Script
# !python src/mvp_run.py

# %% [markdown]
# ## Next Steps: Training on CUB-200
#
# To train on real data, we need to download the CUB-200-2011 dataset.

# %%
# Optional: Download CUB-200 (Takes time)
# !wget https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz
# !tar -xzf CUB_200_2011.tgz
