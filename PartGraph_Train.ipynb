# %% [markdown]
# # PartGraph Training - CUB-200
#
# This notebook trains the PartGraph model (Backbone + Slot Attention) on the CUB-200 dataset using a reconstruction task.

# %%
# 1. Clone/Update Repository
# !git clone https://github.com/alltobebetter/PartGraph-FewShot.git
# %cd PartGraph-FewShot
# !git pull

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Download CUB-200 Dataset
# This might take a few minutes.
# %mkdir -p data
# %cd data
# !wget -N https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz
# !tar -xzf CUB_200_2011.tgz
# %cd ..

# %%
# 4. Run Training
# We use a small batch size to be safe on T4 memory.
# !python src/train_reconstruction.py --data_root ./data --batch_size 32 --epochs 50 --num_slots 5

# %% [markdown]
# ## Visualizing Results
#
# After training starts, check the `checkpoints` folder for `epoch_X_vis.png` images to see if the slots are learning meaningful parts.
